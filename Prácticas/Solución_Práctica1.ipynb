# %% [markdown]
# <a href="https://colab.research.google.com/github/LizethArista/Programacion/blob/main/Pr%C3%A1cticas/Soluci%C3%B3n_Pr%C3%A1ctica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Práctica 1**
# *Profesora: Jessica Santizo Galicia*
#
# *Ayudante: Brenda Lizeth Ramírez Arista*
#
# *Fecha de Entrega: 4 de marzo 2026*
#
# Instrucciones:
#
# * Resuelva cada ejercicio en un archivo .py independiente
# * Para la entrega, súbelos a la carpeta de tu equipo, con una nueva carpeta llamada “Ejercicios individuales” y en el nombre del archivo coloca “P1_Ej1_TUS_INICIALES” y “P1_Ej2_TUS_INICIALES”
# * Utilice snake_case para los identificadores
#
# _____________________________________________________________________________
# RECUERDA QUE …
# El snake_case  una convención de nomenclatura que consiste en escribir nombres de variables, funciones y métodos en minúsculas, separando las palabras con guiones bajos  para mejorar la legibilidad. Por ejemplo: mi_variable_ejemplo
# _____________________________________________________________________________
#
# * Incluye comentarios que expliquen tu lógica
# * Valida que los datos de entrada sean los correctos
# (usa if, else; por ejemplo, si a == 0  “Mensaje de error” ;  else… )

# %% [markdown]
# ## EJERCICIO 1: Ecuación Cuadrática (Discriminante Positivo)
#
# Diseña un programa que solicite al usuario los coeficientes a, b y c de una ecuación cuadrática de la forma:
#   $ ax^2+bx+c=0 $
#
# El programa deberá:
#
# * Validar que a≠0(de lo contrario, no es una ecuación cuadrática)
# * Calcular el discriminante: D=b^2-4ac
# * Si D>0, calcular y mostrar las dos raíces reales usando: $ x_1=(-b+√D)/2a,x_2=(-b-√D)/2a $
# * Si D≤0, mostrar un mensaje indicando que el ejercicio solo resuelve casos con discriminante positivo
#
# **NOTAS:** Antes de iniciar tu codigo debes importar la librería math (línea de cógigo: import math)

# %%
 #Solución

# %% [markdown]
# ## EJERCICIO 2: Registro y Procesamiento de Datos de Ventas
#
# Una tienda requiere registrar la venta de un producto. Diseñe un programa que solicite la siguiente información:
#
# 1.	Nombre del vendedor
# 2.	Clave del producto
# 3.	Cantidad vendida (entero positivo)
# 4.	Precio unitario (flotante positivo)
# 5.	Tipo de cliente ('nuevo' o 'frecuente')
#
# El programa deberá:
#
# *	Calcular el subtotal: cantidad * precio_unitario
#
# *	Aplicar un descuento del 10% si el cliente es 'frecuente'
#
# *	Calcular el total a pagar
#
# *	Mostrar un resumen con los datos ingresados y los cálculos realizados

# %%
#Solución
